# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


product_df = pd.read_csv('C:/Users/j7902/Desktop/Pharma_Analysis/data/clean_product.csv')


drug_type_counts = product_df['PRODUCTTYPENAME'].value_counts()

pharm_class_counts = product_df['PHARM_CLASSES'].value_counts()

print("Most Common Drug Types:")
print(drug_type_counts.head())

print("\nMost Common Pharmaceutical Classes:")
print(pharm_class_counts.head())


plt.figure(figsize=(10,6))
sns.barplot(x=drug_type_counts.head(10).index, y=drug_type_counts.head(10).values, palette='viridis')
plt.title('Top 10 Most Common Drug Types', fontsize=16)
plt.xlabel('Drug Type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.show()


plt.figure(figsize=(10,6))
sns.barplot(x=pharm_class_counts.head(10).index, y=pharm_class_counts.head(10).values, palette='coolwarm')
plt.title('Top 10 Most Common Pharmaceutical Classes', fontsize=16)
plt.xlabel('Pharmaceutical Class', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(7,7))
plt.pie(drug_type_counts.head(5), labels=drug_type_counts.head(5).index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set2'))
plt.title('Top 5 Drug Types Distribution', fontsize=14)
plt.show()

plt.figure(figsize=(7,7))
plt.pie(pharm_class_counts.head(5), labels=pharm_class_counts.head(5).index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set3'))
plt.title('Top 5 Pharmaceutical Classes Distribution', fontsize=14)
plt.show()
# Out:
# Most Common Drug Types:
# PRODUCTTYPENAME
# HUMAN OTC DRUG                 57285
# HUMAN PRESCRIPTION DRUG        55208
# NON-STANDARDIZED ALLERGENIC     2232
# PLASMA DERIVATIVE                327
# VACCINE                          141
# Name: count, dtype: int64
#
# Most Common Pharmaceutical Classes:
# PHARM_CLASSES
# Anti-Inflammatory Agents, Non-Steroidal [CS], Cyclooxygenase Inhibitors [MoA], Nonsteroidal Anti-inflammatory Drug [EPC]    2533
# Corticosteroid Hormone Receptor Agonists [MoA], Corticosteroid [EPC]                                                        2327
# Histamine H1 Receptor Antagonists [MoA], Histamine-1 Receptor Antagonist [EPC]                                              1774
# Atypical Antipsychotic [EPC]                                                                                                1497
# Adrenergic beta-Antagonists [MoA], beta-Adrenergic Blocker [EPC]                                                            1279
# Name: count, dtype: int64
# C:\Users\j7902\AppData\Local\Temp\ipykernel_13144\4254995753.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=drug_type_counts.head(10).index, y=drug_type_counts.head(10).values, palette='viridis')
# C:\Users\j7902\AppData\Local\Temp\ipykernel_13144\4254995753.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pharm_class_counts.head(10).index, y=pharm_class_counts.head(10).values, palette='coolwarm')
